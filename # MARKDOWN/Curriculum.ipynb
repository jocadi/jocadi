// %% [markdown]
// # Jorge Caballero
// 📞+34 697 239 536
// 📧jorgecd92@outlook.es
//
// ## Perfil tecnico
// Técnico de Sistemas Senior y Programador. Dominio de COBOL, SQL y entornos UNIX, con experiencia en bases de datos, web (HTML, CSS, JS) y desarrollo Java/Python/.NET.
// Me caracterizo por un enfoque analítico y una actitud comprometida con la calidad del servicio y del software. Busco aplicar mi experiencia en entornos UNIX, bases de datos y desarrollo Java/.NET/Python, aportando versatilidad, rigor en producción y ganas de crecer profesionalmente.
//
// ## Educacion
// **Desarrollador de Aplicaciones Web**
// IES Azarquiel, Toledo 2015-2017
//
// **Técnico en Sistemas Microinformáticos y Redes**
// IES Julio Verne, Bargas
// (Toledo) 2013-2015
//
// ## Aptitudes
// * Resolución de incidencias técnicas
// * Trabajo en equipo negocio-TI
// * Adaptabilidad a nuevas tecnologías
// * Gestión de tiempo y prioridades
// * Comunicación técnica clara
// * Mejora continua orientada a resultados~
//
// ## Habilidades tecnicas
// * Desarrollo y mantenimiento Java/.NET
// * Administración sistemas Unix
// * Bases de datos: PL/SQL, SQL Server
// * COBOL y Java en sistemas financieros
// * Soporte hardware/software TI
// * Implantación y soporte sistemas FI
// * Entornos banca y alta disponibilidad
//
// ## Competencias
// * Diseño e implantación de módulos
// * Mantenimiento sistemas críticos
// * Migración Access a SQL Server
// * Optimización y mejora de aplicaciones
// * Soporte técnico software/hardware
// * Participación en proyectos bancarios
// * Documentación procesos e incidencias
//
// ## Experiencia
// **Tecnico de Sistemas y Programador**
// INDRA, Banco de España 02/2020–8/2024
// * Mantenimiento de apps PYC, CEP y ABM
// * Entornos Java, .NET y Eclipse IDE
// * Resolución y mejora de incidencias
// * Cliente: Banco de España (a través de Indra)
//
// **Tecnico de Sistemas y Programador**
// INDRA, Sistemas financieros 06/2017–02/2020
// * Desarrollo e implantación de sistemas FI
// * Mantenimiento y soporte en producción
// * Entornos Unix, COBOL, PL/SQL y Java
// * Proyectos: Wilobank, Triodos y AML
//
// **Servicios profesionales externos**
// Consejería de Fomento, Junta de Comunidades de Castilla-La Mancha 04/2017-07/2017
// * Resolución de incidencias TI y hardware
// * Mantenimiento y soporte informático
// * Migración de Access a SQL Server
// * Mantenimiento de bases de datos
//
// ## Cursos - Másters
// **Administracion y Programacion en Sistemas de Planificación de Recursos**
// > IFCT0610 Ayla 690 horas
//
// **Fullstack Web Developer con Javascript**
// > IFCD0022 CEOE CEPYME 280 horas
//
// **Inteligencia Avanzada Aplicada a Empresas**
// > IFCT0019 CEOE CEPYME 280 horas
//
// **Excel Avanzado**
// > FCT36, Fundación Ibercaja 110 horas
//
// **Write Your First Code Using C# 5 horas**
// > Este curso ofrece una introducción completa a la programación en C#, abarcando sus conceptos básicos, sintaxis y aplicación práctica en el desarrollo de software.
//
// **Certificado C# y Unity en Udemy 6,5 horas**
// > Introducción a Unity® 2021 y Tu Primer Videojuego Completo en Udemy 6,5 horas
//
// **Certificado Python TOTAL - Programador Avanzado 31 horas**
// > Aprenderás programación profesional en Python creando programas sólidos y útiles, aplicándolo a proyectos reales cada día, desde juegos hasta IA, Machine Learning y Data Science, dominarás programación orientada a objetos y entenderás temas complejos
//
// **Linux Mastery: Master the Linux Command Line in 11.5 Hours, Udemy**
// > Curso de Unix en la plataforma Udemy
//
// **The Complete Java Certification Course in 17.5 Hours, Udemy**
// > Curso de Java en la plataforma Udemy
//
// **BECA FORMACION COBOL + SQL 120 horas**
// > Lenguajes:- Cobol (Lenguaje de programación)- SQLPlus (Visualización, modificación y creación de BBDD)
//
// **Curso en Metodologías de Gestión de Proyectos 5 horas**
// > Metodología Waterfall y Metodología Agile.
